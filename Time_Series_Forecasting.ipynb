# %% [markdown]
# <a href="https://colab.research.google.com/github/Dinesh5aini/Time-Series-Forecasting/blob/main/Time_Series_Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True
)

csv_path, _ = os.path.splitext(zip_path)
csv_path = os.path.join(csv_path, 'jena_climate_2009_2016.csv')

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
df.index = pd.to_datetime(df['Date Time'], format = '%d.%m.%Y %H:%M:%S')
df
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# ...                                  ...       ...       ...       ...
# 2016-12-31 19:10:00  31.12.2016 19:10:00   1002.18     -0.98    272.01
# 2016-12-31 20:10:00  31.12.2016 20:10:00   1001.40     -1.40    271.66
# 2016-12-31 21:10:00  31.12.2016 21:10:00   1001.19     -2.75    270.32
# 2016-12-31 22:10:00  31.12.2016 22:10:00   1000.65     -2.89    270.22
# 2016-12-31 23:10:00  31.12.2016 23:10:00   1000.11     -3.93    269.23
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# ...

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = [[a] for a in df_as_np[i:i+window_size]]
        X.append(row)
        label = df_as_np[i+window_size]
        y.append(label)
    return np.array(X), np.array(y)

# %%
window_size = 5
X, y = df_to_X_y(temp, window_size)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60000], y[:60000]
X_val, y_val = X[60000:65000], y[60000:65000]
X_test, y_test = X[65000:], y[65000:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((window_size, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model1/mdoel1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), metrics=[RootMeanSquaredError()], optimizer=Adam(learning_rate=0.0001))

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 74.4544 - root_mean_squared_error: 8.3684 - val_loss: 1.1430 - val_root_mean_squared_error: 1.0691
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 2.5781 - root_mean_squared_error: 1.5993 - val_loss: 0.6301 - val_root_mean_squared_error: 0.7938
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 1.0158 - root_mean_squared_error: 1.0073 - val_loss: 0.5574 - val_root_mean_squared_error: 0.7466
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.7540 - root_mean_squared_error: 0.8683 - val_loss: 0.5195 - val_root_mean_squared_error: 0.7208
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.6861 - root_mean_squared_error: 0.8283 - val_loss: 0.5095 - val_root_mean_squared_error: 0.7138
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.6793 - root_mean_squared_error: 0.8232 - val_loss: 0.5375 - val_root_mean_squared_error: 0.7332
# ...

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1/mdoel1.keras')

# %%
train_preds = model1.predict(X_train)
train_results = pd.DataFrame(data={
    'Predictions': train_preds.flatten(),
    'Labels': y_train
})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
#        Predictions  Labels
# 0        -9.900633   -9.67
# 1        -9.711232   -9.17
# 2        -8.873223   -8.10
# 3        -7.412780   -7.66
# 4        -7.249277   -7.04
# ...            ...     ...
# 59995     5.960403    6.07
# 59996     7.261800    9.88
# 59997    12.159679   13.53
# 59998    16.186520   15.43
# 59999    16.312313   15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Predictions'][:100])
plt.plot(train_results['Labels'][:100])
plt.legend(['Predictions', 'Labels'])
plt.show()

# %%
val_preds = model1.predict(X_val)
val_results = pd.DataFrame(data={
    'Predictions': val_preds.flatten(),
    'Labels': y_val
})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Predictions  Labels
# 0       15.433283   14.02
# 1       13.259910   13.67
# 2       13.068982   12.27
# 3       11.591357   11.19
# 4       10.451522   10.85
# ...           ...     ...
# 4995    17.326761   18.27
# 4996    17.376110   17.85
# 4997    17.165993   16.65
# 4998    15.848938   15.85
# 4999    15.081649   15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Predictions'][:100])
plt.plot(val_results['Labels'][:100])
plt.legend(['Predictions', 'Labels'])
plt.show()

# %%
test_preds = model1.predict(X_test)
test_results = pd.DataFrame(data={
    'Predictions': test_preds.flatten(),
    'Labels': y_test
})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Predictions  Labels
# 0       14.417718   13.99
# 1       13.295999   13.46
# 2       12.882042   12.93
# 3       12.473487   12.43
# 4       12.019784   12.17
# ...           ...     ...
# 5081    -0.902776   -0.98
# 5082    -1.273818   -1.40
# 5083    -1.493050   -2.75
# 5084    -3.217057   -2.89
# 5085    -3.012902   -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Predictions'][:100])
plt.plot(test_results['Labels'][:100])
plt.legend(['Predictions', 'Labels'])
plt.show()
